# %% [markdown]
# <a href="https://colab.research.google.com/github/narendrapentu-sys/ADMET/blob/main/flavanoneadmet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to upload your data file:**
#
# 1. Click the folder icon on the left sidebar.
# 2. Click the "Upload to session storage" icon (an arrow pointing up).
# 3. Select the `ADMET.xlsx` file from your computer and upload it.
#
# Once the file is uploaded, you can run the code cell again.

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    cbar=True,
    square=True,
    annot_kws={"size": 8}
)
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.title("ADME Properties Correlation Matrix", fontsize=14)
plt.tight_layout()
plt.show()
